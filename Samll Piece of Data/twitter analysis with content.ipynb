# %%
#import the required libriary used for the analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json as js
import ast
import re
import networkx as nx
from datetime import datetime

# %%
#open file and handle the issue of single quotes
with open(r"corona_tweets_01_includes.tweets.txt", encoding="utf8") as corona_file:
    tw=[]
    line= corona_file.readlines()
    for row in range(len(line)):
        temp = ast.literal_eval(line[row])
        tw.append(temp)

    tws_df=pd.DataFrame(tw)
    print(tws_df.head())
# Out:
#             author_id lang                                     public_metrics  \
# 0           298320111   en  {'retweet_count': 11963, 'reply_count': 540, '...
# 1            20711389   en  {'retweet_count': 48775, 'reply_count': 2781, ...
# 2  812135885328236551   en  {'retweet_count': 104, 'reply_count': 23, 'lik...
# 3           119599035   en  {'retweet_count': 85671, 'reply_count': 99, 'l...
# 4           100420381   en  {'retweet_count': 30587, 'reply_count': 8313, ...
#
#                                             entities  \
# 0  {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 1  {'urls': [{'start': 28, 'end': 51, 'url': 'htt...
# 2  {'urls': [{'start': 27, 'end': 50, 'url': 'htt...
# 3                                                NaN
# 4  {'urls': [{'start': 210, 'end': 233, 'url': 'h...
#
#                                          attachments                   id  \
# 0          {'media_keys': ['7_1240691535768780800']}  1240691667738300416
# 1                                                NaN  1240420911695577088
# 2                                                NaN  1240727611199770624
# 3                                                NaN  1240295805472452614
# 4  {'media_keys': ['3_1240700809773551621', '3_12...  1240701140141879298
#
#                                  context_annotations              source  \
# 0  [{'domain': {'id': '123', 'name': 'Ongoing New...  Twitter for iPhone
# 1  [{'domain': {'id': '123', 'name': 'Ongoing New...  Twitter for iPhone
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...     Twitter Web App
# 3  [{'domain': {'id': '123', 'name': 'Ongoing New...  Twitter for iPhone
# 4  [{'domain': {'id': '10', 'name': 'Person', 'de...     Twitter Web App
#
#                  created_at  possibly_sensitive  \
# 0  2020-03-19T17:28:39.000Z               False
# 1  2020-03-18T23:32:45.000Z               False
# 2  2020-03-19T19:51:28.000Z               False
# 3  2020-03-18T15:15:38.000Z               False
# 4  2020-03-19T18:06:17.000Z               False
#
#                                                 text  \
# 0  here’s a deleted scene from TWD’s special on c...
# 1  Everyone in this looks sick https://t.co/Mf8pW...
# 2  Good.\n\nIt came from China. https://t.co/JeZo...
# 3  Corona day 3: it just feels like Sunday again ...
# 4  Close up of President @realDonaldTrump notes i...
#
#                                    referenced_tweets  geo in_reply_to_user_id  \
# 0                                                NaN  NaN                 NaN
# 1  [{'type': 'quoted', 'id': '1240371160078000128'}]  NaN                 NaN
# 2  [{'type': 'quoted', 'id': '1240701140141879298'}]  NaN                 NaN
# 3                                                NaN  NaN                 NaN
# 4                                                NaN  NaN                 NaN
#
#   withheld
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Task 1** Visualize the histagram

# %%
#define the helper function to do the function take out the string of time and summarize them into the hour
def process_time(df):
    time_str = df['created_at'][11:19]
    time_whole = datetime.strptime(time_str, '%H:%M:%S')
    return int(datetime.strftime(time_whole, '%H'))

#make an empty column and apply the function
tws_df['time'] = np.NaN
tws_df['time'] = tws_df.apply(process_time, axis=1)

# %%
#plot the histogram graph
plt.figure(figsize=(16,12)) 
plt.hist(tws_df['time'],bins=range(0, 24, 1) )
plt.xlabel('Time')
plt.ylabel('Number of Tweets')
plt.title('Number of Tweets VS Time in hour scale')
plt.show()

# %% [markdown]
# **Task 2** networkx for the relations of users

# %%
#take out the value of the reference ID for the user

def refer_id(df):
    #check if there is reference tweets
    if isinstance(df['referenced_tweets'],float):
        return -1
    else:
        return int(df['referenced_tweets'][0]['id'])

    
# make an empth column and apply the function 
tws_df['reference_id'] = np.NaN

tws_df['reference_id']= tws_df.apply(refer_id,axis = 1)

# %%
#take out the id of the user
def users_id(df):
    return int(df['id'])

# make an empth column and apply the function 
tws_df['user_id']= np.NaN
tws_df['user_id']= tws_df.apply(users_id,axis=1)

# %%
#sample rate of 0.00325 (1000 samples)
G = nx.Graph()
G = nx.from_pandas_edgelist(tws_df.sample(frac= 0.00325),'reference_id','user_id')

plt.figure(figsize=(16,12)) 
nx.draw(G,node_size=5)
plt.title('Relations of reference twitters with a sample of 2500 samples')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#sample rate of 0.0078125 (2500 samples)
G = nx.Graph()
G = nx.from_pandas_edgelist(tws_df.sample(frac= 0.0078125),'reference_id','user_id')

plt.figure(figsize=(16,12)) 
nx.draw(G,node_size=5)
plt.title('Relations of reference twitters with a sample of 2500 samples')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#sample rate of 0.015625 (5000 samples)
G = nx.Graph()
G = nx.from_pandas_edgelist(tws_df.sample(frac= 0.015625),'reference_id','user_id')

plt.figure(figsize=(16,12)) 
nx.draw(G,node_size=3)
plt.title('Relations of reference twitters with a sample of 5000 samples')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#sample rate of 0.03125 (10000 samples)
G = nx.Graph()
G = nx.from_pandas_edgelist(tws_df.sample(frac= 0.03125),'reference_id','user_id')

plt.figure(figsize=(16,12)) 
nx.draw(G,node_size=2)
plt.title('Relations of reference twitters with a sample of 10000 samples')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Task 3** Visualize the scatter plot between mention counts and retweet counts and likes counts

# %%
#take out the number of the retweets and add the column
def count_retweets(df):
    rtw_dic =  df["public_metrics"]
    
    return rtw_dic.get("retweet_count")
    
#make an empty column and apply the function 
tws_df['retweets_counts'] = np.NaN
tws_df['retweets_counts'] = tws_df.apply(count_retweets, axis=1)

# %%
#take out the number of mention counts and make it into a new column

def count_mentions(df):
    #check if there is no entities as a float, and if there is, check if there is mentions
    if isinstance(df.loc['entities'],float):
        return 0
    elif 'mentions' in df['entities']:
        return len(df['entities'].get('mentions'))
    else:
        return 0
    
#make an empty column and apply the function 
tws_df['mention_counts'] = np.NaN
tws_df['mention_counts'] = tws_df.apply(count_mentions, axis=1)

# %%
#draw the scatter plot
plt.figure(figsize=(16,12)) 
plt.scatter(tws_df['mention_counts'],tws_df['retweets_counts'])
plt.xlabel('Mention Counts')
plt.ylabel('Retweets Counts')
plt.title('Number of Mention Counts VS Number of Retweets CountS')
plt.show()

# %%
#take out the number of the likes and add the column
def count_likes(df):
    rtw_dic =  df["public_metrics"]
    
    return rtw_dic.get("like_count")
    
#make an empty column and apply the function 
tws_df['likes_counts'] = np.NaN
tws_df['likes_counts'] = tws_df.apply(count_retweets, axis=1)

# %%
#draw the scatter plot
plt.figure(figsize=(16,12)) 
plt.scatter(tws_df['likes_counts'],tws_df['retweets_counts'])
plt.xlabel('Likes Counts')
plt.ylabel('Retweets Counts')
plt.title('Number of like Counts VS Number of Retweets CountS')
plt.show()

# %%
#draw the scatter plot
plt.figure(figsize=(16,12)) 
plt.scatter(tws_df['mention_counts'],tws_df['likes_counts'])
plt.xlabel('Mentions Counts')
plt.ylabel('Likes Counts')
plt.title('Number of like Counts VS Number of mention Count')
plt.show()

# %%
threedee  = plt.figure().gca(projection='3d')
threedee .scatter(tws_df['mention_counts'],tws_df['likes_counts'],tws_df['retweets_counts'])
threedee.set_title('3D graph Number of like Counts VS Number of mention Counts VS Number of like Counts VS Number of mention Counts')
threedee .set_xlabel('Mentions Counts')
threedee .set_ylabel('Likes Counts')
threedee .set_zlabel('Retweets Counts')
plt.show()
